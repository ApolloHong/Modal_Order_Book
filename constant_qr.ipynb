# %% [markdown]
# ## Simulation de deux premières limites à intensités constantes

# %%
import numpy as np
# Out:
# Exception in callback BaseAsyncIOLoop._handle_events()
# handle: <Handle BaseAsyncIOLoop._handle_events()>
# Traceback (most recent call last):
#   File "C:\Users\zhang\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\zhang\OneDrive\Documents\_Tom\Polytechnique\2A\APM_43M02 - Simulation numérique aléatoire\TD\Lib\site-packages\tornado\platform\asyncio.py", line 208, in _handle_events
#     handler_func(fileobj, events)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\zhang\OneDrive\Documents\_Tom\Polytechnique\2A\APM_43M02 - Simulation numérique aléatoire\TD\Lib\site-packages\zmq\eventloop\zmqstream.py", line 600, in _handle_events
#     self._handle_recv()
#     ~~~~~~~~~~~~~~~~~^^
# ...
